# %%
# !pip install resampy
# !pip install git+https://github.com/qubvel/classification_models.git
# !pip install keras-radam
# !pip install adabelief-tf==0.1.0
# !pip install keras-rectified-adam
# !pip install keras-adabound
# !pip install git+https://github.com/tensorflow/addons
# Out:
# Collecting resampy
#   Downloading resampy-0.4.2-py3-none-any.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 7.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from resampy) (1.23.5)
# Requirement already satisfied: numba>=0.53 in /usr/local/lib/python3.10/dist-packages (from resampy) (0.56.4)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.53->resampy) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba>=0.53->resampy) (67.7.2)
# Installing collected packages: resampy
# Successfully installed resampy-0.4.2
# Collecting git+https://github.com/qubvel/classification_models.git
#   Cloning https://github.com/qubvel/classification_models.git to /tmp/pip-req-build-ikwj6qew
#   Running command git clone --filter=blob:none --quiet https://github.com/qubvel/classification_models.git /tmp/pip-req-build-ikwj6qew
#   Resolved https://github.com/qubvel/classification_models.git to commit a0f006e05485a34ccf871c421279864b0ccd220b
#   Running command git submodule update --init --recursive -q
#   Preparing metadata (setup.py) ... done
# Collecting keras_applications<=1.0.8,>=1.0.7 (from image-classifiers==1.0.0)
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 926.8 kB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from keras_applications<=1.0.8,>=1.0.7->image-classifiers==1.0.0) (1.23.5)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras_applications<=1.0.8,>=1.0.7->image-classifiers==1.0.0) (3.9.0)
# Building wheels for collected packages: image-classifiers
#   Building wheel for image-classifiers (setup.py) ... done
#   Created wheel for image-classifiers: filename=image_classifiers-1.0.0-py3-none-any.whl size=20027 sha256=c7f8da9dfbb0a4f573c15500a764cfb1c46a349507608e4f85e76ac8c926dec6
#   Stored in directory: /tmp/pip-ephem-wheel-cache-icvufko_/wheels/f5/13/cb/b1dbd79043c5a389742e422859b0b663adcd7b5c220928c339
# Successfully built image-classifiers
# Installing collected packages: keras_applications, image-classifiers
# Successfully installed image-classifiers-1.0.0 keras_applications-1.0.8
# Collecting keras-radam
#   Downloading keras-radam-0.15.0.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras-radam) (1.23.5)
# Requirement already satisfied: Keras in /usr/local/lib/python3.10/dist-packages (from keras-radam) (2.12.0)
# Building wheels for collected packages: keras-radam
#   Building wheel for keras-radam (setup.py) ... done
#   Created wheel for keras-radam: filename=keras_radam-0.15.0-py3-none-any.whl size=14667 sha256=b7c5d4432bdd0034c8db08e9d06ba639ffb08373ab2fecb4b6236da398a22539
#   Stored in directory: /root/.cache/pip/wheels/e6/e0/44/3d07c185de530721a196a5368d48f6256233337e2c90159f24
# Successfully built keras-radam
# Installing collected packages: keras-radam
# Successfully installed keras-radam-0.15.0
# Collecting adabelief-tf==0.1.0
#   Downloading adabelief_tf-0.1.0-py3-none-any.whl (6.3 kB)
# Requirement already satisfied: tensorflow>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from adabelief-tf==0.1.0) (2.12.0)
# Collecting tensorflow-addons (from adabelief-tf==0.1.0)
#   Downloading tensorflow_addons-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (612 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 612.1/612.1 kB 6.0 MB/s eta 0:00:00
# Collecting colorama>=0.4.0 (from adabelief-tf==0.1.0)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: tabulate>=0.7 in /usr/local/lib/python3.10/dist-packages (from adabelief-tf==0.1.0) (0.9.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.0.0->adabelief-tf==0.1.0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.0.0->adabelief-tf==0.1.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.0.0->adabelief-tf==0.1.0) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.0.0->adabelief-tf==0.1.0) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.0.0->adabelief-tf==0.1.0) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.0.0->adabelief-tf==0.1.0) (1.57.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.0.0->adabelief-tf==0.1.0) (3.9.0)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.0.0->adabelief-tf==0.1.0) (0.4.14)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.0.0->adabelief-tf==0.1.0) (2.12.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.0.0->adabelief-tf==0.1.0) (16.0.6)
# Requirement already satisfied: numpy<1.24,>=1.22 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.0.0->adabelief-tf==0.1.0) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.0.0->adabelief-tf==0.1.0) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.0.0->adabelief-tf==0.1.0) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.0.0->adabelief-tf==0.1.0) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.0.0->adabelief-tf==0.1.0) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.0.0->adabelief-tf==0.1.0) (1.16.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.0.0->adabelief-tf==0.1.0) (2.12.3)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.0.0->adabelief-tf==0.1.0) (2.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.0.0->adabelief-tf==0.1.0) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.0.0->adabelief-tf==0.1.0) (4.7.1)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.0.0->adabelief-tf==0.1.0) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.0.0->adabelief-tf==0.1.0) (0.33.0)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow-addons->adabelief-tf==0.1.0)
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow>=2.0.0->adabelief-tf==0.1.0) (0.41.2)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.15->tensorflow>=2.0.0->adabelief-tf==0.1.0) (0.2.0)
# Requirement already satisfied: scipy>=1.7 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.15->tensorflow>=2.0.0->adabelief-tf==0.1.0) (1.10.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=2.0.0->adabelief-tf==0.1.0) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=2.0.0->adabelief-tf==0.1.0) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=2.0.0->adabelief-tf==0.1.0) (3.4.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=2.0.0->adabelief-tf==0.1.0) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=2.0.0->adabelief-tf==0.1.0) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=2.0.0->adabelief-tf==0.1.0) (2.3.7)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow>=2.0.0->adabelief-tf==0.1.0) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow>=2.0.0->adabelief-tf==0.1.0) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow>=2.0.0->adabelief-tf==0.1.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow>=2.0.0->adabelief-tf==0.1.0) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow>=2.0.0->adabelief-tf==0.1.0) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow>=2.0.0->adabelief-tf==0.1.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow>=2.0.0->adabelief-tf==0.1.0) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow>=2.0.0->adabelief-tf==0.1.0) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow>=2.0.0->adabelief-tf==0.1.0) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow>=2.0.0->adabelief-tf==0.1.0) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow>=2.0.0->adabelief-tf==0.1.0) (3.2.2)
# Installing collected packages: typeguard, colorama, tensorflow-addons, adabelief-tf
# Successfully installed adabelief-tf-0.1.0 colorama-0.4.6 tensorflow-addons-0.21.0 typeguard-2.13.3
# Collecting keras-rectified-adam
#   Downloading keras-rectified-adam-0.20.0.tar.gz (7.0 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras-rectified-adam) (1.23.5)
# Requirement already satisfied: Keras in /usr/local/lib/python3.10/dist-packages (from keras-rectified-adam) (2.12.0)
# Building wheels for collected packages: keras-rectified-adam
#   Building wheel for keras-rectified-adam (setup.py) ... done
#   Created wheel for keras-rectified-adam: filename=keras_rectified_adam-0.20.0-py3-none-any.whl size=8255 sha256=5df3cebb7f8a72e4e199c5548a416576eb576bf484a916ea733a653eda163a3c
#   Stored in directory: /root/.cache/pip/wheels/24/fe/0f/dcf898210ceef6ae45cea51d3d27765f38bce2b4dc8e88245f
# Successfully built keras-rectified-adam
# Installing collected packages: keras-rectified-adam
# Successfully installed keras-rectified-adam-0.20.0
# Collecting keras-adabound
#   Downloading keras-adabound-0.6.0.tar.gz (5.5 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras-adabound) (1.23.5)
# Requirement already satisfied: Keras in /usr/local/lib/python3.10/dist-packages (from keras-adabound) (2.12.0)
# Requirement already satisfied: typeguard in /usr/local/lib/python3.10/dist-packages (from keras-adabound) (2.13.3)
# Building wheels for collected packages: keras-adabound
#   Building wheel for keras-adabound (setup.py) ... done
#   Created wheel for keras-adabound: filename=keras_adabound-0.6.0-py3-none-any.whl size=6587 sha256=0a1d8fc8422d3ba72e9bbc79a8e9675b08b1d14a883ca5e18fa5681e9dddfa51
#   Stored in directory: /root/.cache/pip/wheels/c7/0c/82/026bbf0810e0ac6d6b6686fef3891d052534ecb440a0c28c19
# Successfully built keras-adabound
# Installing collected packages: keras-adabound
# Successfully installed keras-adabound-0.6.0
# Collecting git+https://github.com/tensorflow/addons
#   Cloning https://github.com/tensorflow/addons to /tmp/pip-req-build-mdr4pk8y
#   Running command git clone --filter=blob:none --quiet https://github.com/tensorflow/addons /tmp/pip-req-build-mdr4pk8y
#   Resolved https://github.com/tensorflow/addons to commit 5dd5f65827c37e9b9b616b79ed93da856b57ffe5
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons==0.22.0.dev0) (2.13.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons==0.22.0.dev0) (23.1)
# Building wheels for collected packages: tensorflow-addons
#   Building wheel for tensorflow-addons (pyproject.toml) ... done
#   Created wheel for tensorflow-addons: filename=tensorflow_addons-0.22.0.dev0-cp310-cp310-linux_x86_64.whl size=504340 sha256=fed291b400fd59fbc6ac2ec8a9ac2476d5fe6e8344e6111169b48016a716769e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-41a0krt1/wheels/c8/c8/63/bfb8b22b6f020ea614f0d18e300e0f9cab33a0d62d6a7a8ef3
# Successfully built tensorflow-addons
# Installing collected packages: tensorflow-addons
#   Attempting uninstall: tensorflow-addons
#     Found existing installation: tensorflow-addons 0.21.0
#     Uninstalling tensorflow-addons-0.21.0:
#       Successfully uninstalled tensorflow-addons-0.21.0
# Successfully installed tensorflow-addons-0.22.0.dev0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import librosa
import librosa.display
import numpy as np
from tqdm import tqdm
import resampy

from sklearn.preprocessing import LabelEncoder
from keras.utils import np_utils

import tensorflow as tf
from keras.utils import to_categorical
from keras.models import Sequential, load_model
from keras.layers import Dense , Activation , Dropout , SpatialDropout2D, Conv2D, MaxPooling2D, BatchNormalization, GlobalAveragePooling2D, ReLU, Flatten
from keras.optimizers import Adam

from keras import backend as keras_backend
from keras.callbacks import ModelCheckpoint
from keras.regularizers import l2

from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split

from adabelief_tf import AdaBeliefOptimizer
from keras_radam.training import RAdamOptimizer
from keras_adabound import AdaBound
import tensorflow_addons
from keras.layers import LSTM,Input
from keras.layers import Bidirectional

import seaborn as sns
import random
import math

from glob import glob
from itertools import cycle

sns.set_theme(style="white", palette=None)
color_pal = plt.rcParams["axes.prop_cycle"].by_key()["color"]
color_cycle = cycle(plt.rcParams["axes.prop_cycle"].by_key()["color"])
# Out:
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
def create_dataset_df(csv_file):
    dataset_df = pd.read_csv(csv_file)
    filepaths = []
    for i, row in dataset_df.iterrows():
        filepaths.append(os.path.join('/content/drive/MyDrive/ThesisData/', 'File'+str(row['fold']), row['slice_file_name']))
    dataset_df['filepath'] = filepaths
    return dataset_df

# %%
df = create_dataset_df('/content/drive/MyDrive/ThesisData/ThesisLionMD.csv')

# %%
def get_duration(file_name):

    # load the audio file
    audio,sample_rate = librosa.load(file_name,res_type='kaiser_fast')

    time = librosa.get_duration(y=audio, sr=sample_rate)

    return time

# %%
duration = []

for index_num, row in tqdm(df.iterrows()):

    # get the file
    file_name = os.path.join(os.path.abspath('drive/MyDrive/ThesisData/'),'File'+str(row["fold"])+'/',str(row['slice_file_name']))

    time = get_duration(file_name)

    duration.append(time)
# Out:
# 3480it [10:48,  5.37it/s]

# %%
df['duration'] = duration
sorted_df = df[df.duration <= 3]
sorted_df['class'].value_counts()
# Out:
# Grunt    1491
# Roar      993
# IRoar     987
# Name: class, dtype: int64

# %%
class_map = {'1' : 'IRoar', '0' : 'Roar', '2' : 'Grunt'}
pd.DataFrame(sorted(list(class_map.items())))
# Out:
#    0      1
# 0  0   Roar
# 1  1  IRoar
# 2  2  Grunt

# %%
appended = []
for i in range(1,4):
    appended.append(sorted_df[sorted_df.fold == i]['class'].value_counts())

class_distribution = pd.DataFrame(appended)
class_distribution = class_distribution.reset_index()
class_distribution['index'] = ["fold"+str(x) for x in range(1,4)]
class_distribution
# Out:
#    index  Grunt  Roar  IRoar
# 0  fold1    496   332    326
# 1  fold2    496   329    329
# 2  fold3    499   332    332

# %%
# Randomly select one sample of each class
random_samples = sorted_df.groupby('class').sample(1)
audio_samples, labels = random_samples['filepath'].tolist(), random_samples['class'].tolist()

# Visualize the waveforms
fig, axs = plt.subplots(3, 1, figsize=(15,10))
index = 0
for col in range(3):
    audio_file, sample_rate = librosa.load(audio_samples[index])
    librosa.display.waveshow(y=audio_file, sr=sample_rate, ax=axs[col])
    axs[col].set_title('{}'.format(labels[index]))
    index += 1
fig.tight_layout()

# %%
plt.hist(sorted_df['duration'], rwidth=0.9, color='#86bf91')

plt.xlabel('Duration')
plt.ylabel('Population')
plt.title('Histogram of audio lengths')
plt.grid(False)
plt.show()

# Count samples with duration > 3 sec
gt_3sec = sorted_df['duration'][(sorted_df['duration'] > 3)].count()
gt_2sec = sorted_df['duration'][(sorted_df['duration'] > 2) & (sorted_df['duration'] < 3)].count()
lt_2sec = sorted_df['duration'][(sorted_df['duration'] > 1) & (sorted_df['duration'] < 2)].count()
lt_1sec = sorted_df['duration'][sorted_df['duration'] < 1].count()

# Display counts of interest
print("Greater than 3 seconds: {}".format(gt_3sec))
print("Lower than 3 but greater than 2 seconds: {}".format(gt_2sec))
print("Lower than 2 but greater than 1 seconds: {}".format(lt_2sec))
print("Lower than 1 seconds: {}".format(lt_1sec))
# Out:
# Greater than 3 seconds: 0
# Lower than 3 but greater than 2 seconds: 152
# Lower than 2 but greater than 1 seconds: 1601
# Lower than 1 seconds: 1718

# %%
# Feature extraction using librosa

data = []
labels = []

start = 0
end = 0

path='/content/drive/MyDrive/ThesisData/File'
for i in tqdm(range(len(sorted_df))):
    fold_no=str(sorted_df.iloc[i]["fold"])
    file=sorted_df.iloc[i]["slice_file_name"]
    label=sorted_df.iloc[i]["classID"]
    filename=path+fold_no+"/"+file
    y,sr=librosa.load(filename, res_type='kaiser_fast')
    #trim the audio file
    y_trimmed, _ = librosa.effects.trim(y)
    if sorted_df.iloc[i]["class"] == "IRoar":
      start = 22000
      end= 26000
    elif sorted_df.iloc[i]["class"] == "Roar":
      start = 7000
      end= 11000
    elif sorted_df.iloc[i]["class"] == "Grunt":
      start = 2000
      end= 6000
    mfccs = np.mean(librosa.feature.mfcc(y=y_trimmed[start:end], sr=sr, n_mfcc=40).T,axis=0)

    data.append(mfccs)
    labels.append(label)
# Out:
#   0%|          | 7/3471 [00:02<12:06,  4.77it/s]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1208
#   warnings.warn(
#   1%|          | 25/3471 [00:03<04:45, 12.07it/s]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=784
#   warnings.warn(
#   1%|▏         | 51/3471 [00:05<03:20, 17.04it/s]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1981
#   warnings.warn(
#   2%|▏         | 55/3471 [00:05<03:48, 14.92it/s]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=0
#   warnings.warn(
#   2%|▏         | 82/3471 [00:06<02:16, 24.88it/s]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=2035
#   warnings.warn(
#   3%|▎         | 121/3471 [00:08<01:42, 32.77it/s]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=886
#   warnings.warn(
#   7%|▋         | 237/3471 [00:12<02:00, 26.84it/s]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=104
#   warnings.warn(
#   8%|▊         | 266/3471 [00:13<01:54, 28.03it/s]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1839
#   warnings.warn(
#  10%|█         | 364/3471 [00:19<03:22, 15.37it/s]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1529
#   warnings.warn(
#  11%|█         | 379/3471 [00:20<03:05, 16.63it/s]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1233
#   warnings.warn(
#  11%|█         | 388/3471 [00:20<03:10, 16.17it/s]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1871
#   warnings.warn(
#  11%|█▏        | 392/3471 [00:21<03:55, 13.09it/s]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=488
#   warnings.warn(
#  15%|█▍        | 514/3471 [00:25<01:45, 27.99it/s]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1647
#   warnings.warn(
#  17%|█▋        | 605/3471 [00:28<01:57, 24.32it/s]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=987
#   warnings.warn(
#  18%|█▊        | 640/3471 [00:29<01:35, 29.65it/s]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1486
#   warnings.warn(
#  19%|█▉        | 671/3471 [00:30<01:41, 27.69it/s]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1010
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=299
#   warnings.warn(
#  22%|██▏       | 771/3471 [00:37<01:46, 25.44it/s]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1704
#   warnings.warn(
#  25%|██▍       | 851/3471 [00:39<01:34, 27.79it/s]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1484
#   warnings.warn(
#  26%|██▌       | 890/3471 [00:41<01:28, 29.15it/s]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1190
#   warnings.warn(
#  26%|██▋       | 913/3471 [00:42<01:23, 30.56it/s]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1534
#   warnings.warn(
#  27%|██▋       | 950/3471 [00:43<01:19, 31.89it/s]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=985
#   warnings.warn(
#  28%|██▊       | 985/3471 [00:44<01:40, 24.76it/s]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=201
#   warnings.warn(
#  29%|██▉       | 1010/3471 [00:45<01:27, 28.08it/s]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1741
#   warnings.warn(
#  37%|███▋      | 1292/3471 [00:58<01:13, 29.49it/s]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1596
#   warnings.warn(
#  41%|████      | 1411/3471 [01:03<02:23, 14.31it/s]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=5
#   warnings.warn(
#  41%|████      | 1431/3471 [01:04<02:36, 13.02it/s]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1764
#   warnings.warn(
#  43%|████▎     | 1483/3471 [01:07<01:32, 21.52it/s]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=406
#   warnings.warn(
#  43%|████▎     | 1501/3471 [01:08<01:19, 24.86it/s]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1977
#   warnings.warn(
#  44%|████▎     | 1515/3471 [01:09<01:14, 26.26it/s]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=803
#   warnings.warn(
#  46%|████▌     | 1603/3471 [01:12<01:00, 30.73it/s]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1922
#   warnings.warn(
#  47%|████▋     | 1637/3471 [01:13<00:58, 31.13it/s]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=984
#   warnings.warn(
#  48%|████▊     | 1661/3471 [01:14<01:02, 28.74it/s]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=547
#   warnings.warn(
#  51%|█████     | 1773/3471 [01:19<01:44, 16.27it/s]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1896
#   warnings.warn(
#  52%|█████▏    | 1791/3471 [01:20<01:52, 14.88it/s]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1867
#   warnings.warn(
#  52%|█████▏    | 1815/3471 [01:22<02:01, 13.65it/s]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1730
#   warnings.warn(
#  54%|█████▍    | 1867/3471 [01:24<01:01, 26.08it/s]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=726
#   warnings.warn(
#  54%|█████▍    | 1871/3471 [01:24<00:57, 27.95it/s]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=294
#   warnings.warn(
#  57%|█████▋    | 1983/3471 [01:28<00:55, 26.67it/s]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1983
#   warnings.warn(
#  57%|█████▋    | 1990/3471 [01:28<00:53, 27.71it/s]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1986
#   warnings.warn(
#  60%|█████▉    | 2076/3471 [01:31<00:43, 31.89it/s]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1997
#   warnings.warn(
#  63%|██████▎   | 2200/3471 [01:38<00:50, 25.01it/s]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1842
#   warnings.warn(
#  70%|███████   | 2431/3471 [01:47<00:34, 29.90it/s]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=680
#   warnings.warn(
#  71%|███████   | 2465/3471 [01:49<01:06, 15.05it/s]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1980
#   warnings.warn(
#  73%|███████▎  | 2527/3471 [01:53<01:05, 14.36it/s]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=101
#   warnings.warn(
#  73%|███████▎  | 2550/3471 [01:54<00:45, 20.12it/s]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1501
#   warnings.warn(
#  76%|███████▌  | 2625/3471 [01:57<00:30, 27.91it/s]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1205
#   warnings.warn(
#  77%|███████▋  | 2662/3471 [01:58<00:31, 25.47it/s]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1044
#   warnings.warn(
#  85%|████████▌ | 2953/3471 [02:11<00:16, 30.72it/s]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1707
#   warnings.warn(
#  91%|█████████ | 3146/3471 [02:19<00:11, 27.32it/s]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1311
#   warnings.warn(
#  92%|█████████▏| 3204/3471 [02:22<00:16, 16.64it/s]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=2006
#   warnings.warn(
#  93%|█████████▎| 3233/3471 [02:24<00:20, 11.40it/s]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1836
#   warnings.warn(
#  98%|█████████▊| 3408/3471 [02:31<00:02, 25.24it/s]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1793
#   warnings.warn(
#  99%|█████████▉| 3447/3471 [02:32<00:00, 24.22it/s]/usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=153
#   warnings.warn(
# 100%|██████████| 3471/3471 [02:33<00:00, 22.61it/s]

# %%
data=np.array(data)
labels=np.array(labels)

# %%
# Shuffle the data
indices = np.arange(len(data))
np.random.shuffle(indices)
data = data[indices]
labels = labels[indices]

# %%
#reshaping to 3D
data=np.reshape(data,(data.shape[0], 1,40))
data.shape
# Out:
# (3471, 1, 40)

# %%
#converting to one hot
labels = to_categorical(labels, num_classes=3)
labels = np.reshape(labels, (labels.shape[0], 1,3))
labels.shape
# Out:
# (3471, 1, 3)

# %%
from keras.layers import Bidirectional

# %%
from keras.layers import LSTM,Input

# Model
model = Sequential()
model.add(Bidirectional(LSTM(40,return_sequences=True, dropout=0.25,
recurrent_dropout=0.1),input_shape=(1,40)))
#model.add(LSTM(40,input_shape=(1,40),return_sequences=True))
model.add(Dense(512,activation ='relu'))
model.add(Dropout(0.2))
model.add(Dense(3,activation ='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (None, 1, 80)            25920
#  l)
#
#  dense (Dense)               (None, 1, 512)            41472
#
#  dropout (Dropout)           (None, 1, 512)            0
#
#  dense_1 (Dense)             (None, 1, 3)              1539
#
# =================================================================
# Total params: 68,931
# Trainable params: 68,931
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Split the data into training and testing sets
split_ratio = 0.6
split_index = int(len(data) * split_ratio)
X_train, X_test = data[:split_index], data[split_index:]
y_train, y_test = labels[:split_index], labels[split_index:]

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((2082, 1, 40), (1389, 1, 40), (2082, 1, 3), (1389, 1, 3))

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import time
batch_size = 50

# %%
# Function to calculate the size of a NumPy array in bytes
def get_size_in_bytes(arr):

    return arr.nbytes

# %%
# Training and sequential testing
start_time = time.time()
total_data_read_bytes = 0  # Counter to keep track of data read in bytes across all epochs

for epoch in range(30):  # Adjust the number of epochs as needed
    # Use model.fit to train the model with batch_size and verbose set
    #history = model.fit(X_train, y_train, epochs=1, batch_size=batch_size, verbose=1)
    history = model.fit(X_train, y_train, batch_size=batch_size, epochs=1, verbose=1)

    # Calculate the number of samples read in this epoch
    num_samples_read_bytes = get_size_in_bytes(X_train)

    total_data_read_bytes += num_samples_read_bytes  # Update the total count

    # Predict probabilities for test set
    predict_x = model.predict(X_test)
    predict_x=np.reshape(predict_x,(predict_x.shape[0],3))
    y_test=np.reshape(y_test,(y_test.shape[0] ,3))

    # Get predicted labels
    y_pred = np.argmax(predict_x, axis=1)
    y_trues = np.argmax(y_test, axis=1)


    # Make predictions on the entire test set
    #predict_x=model.predict(X_test)
    #y_pred=np.argmax(predict_x,axis=1)

    #y_test = np.argmax(y_test, axis=0)

    #print(y_test.shape, y_pred.shape)

    # Calculate accuracy for early classification
    accuracy = accuracy_score(y_trues, y_pred)
    print(f'Epoch {epoch + 1}: Early Accuracy = {accuracy:.2f}, Data Read in Epoch (bytes) = {num_samples_read_bytes}, Total Data Read (bytes) = {total_data_read_bytes}')

    # Check for early stopping based on a predefined accuracy threshold
    if accuracy >= 0.80:  # Adjust the threshold as needed
        break

end_time = time.time()

print(f'Training and Sequential Testing Time: {end_time - start_time:.2f} seconds')
# Out:
# 42/42 [==============================] - 6s 8ms/step - loss: 0.9135 - accuracy: 0.5802
# 44/44 [==============================] - 1s 2ms/step
# Epoch 1: Early Accuracy = 0.70, Data Read in Epoch (bytes) = 333120, Total Data Read (bytes) = 333120
# 42/42 [==============================] - 0s 8ms/step - loss: 0.6890 - accuracy: 0.7161
# 44/44 [==============================] - 0s 2ms/step
# Epoch 2: Early Accuracy = 0.75, Data Read in Epoch (bytes) = 333120, Total Data Read (bytes) = 666240
# 42/42 [==============================] - 0s 8ms/step - loss: 0.6547 - accuracy: 0.7454
# 44/44 [==============================] - 0s 2ms/step
# Epoch 3: Early Accuracy = 0.78, Data Read in Epoch (bytes) = 333120, Total Data Read (bytes) = 999360
# 42/42 [==============================] - 0s 8ms/step - loss: 0.6123 - accuracy: 0.7589
# 44/44 [==============================] - 0s 2ms/step
# Epoch 4: Early Accuracy = 0.78, Data Read in Epoch (bytes) = 333120, Total Data Read (bytes) = 1332480
# 42/42 [==============================] - 1s 14ms/step - loss: 0.6035 - accuracy: 0.7690
# 44/44 [==============================] - 0s 3ms/step
# Epoch 5: Early Accuracy = 0.79, Data Read in Epoch (bytes) = 333120, Total Data Read (bytes) = 1665600
# 42/42 [==============================] - 1s 13ms/step - loss: 0.5941 - accuracy: 0.7622
# 44/44 [==============================] - 0s 3ms/step
# Epoch 6: Early Accuracy = 0.79, Data Read in Epoch (bytes) = 333120, Total Data Read (bytes) = 1998720
# 42/42 [==============================] - 1s 14ms/step - loss: 0.5744 - accuracy: 0.7767
# 44/44 [==============================] - 0s 3ms/step
# Epoch 7: Early Accuracy = 0.79, Data Read in Epoch (bytes) = 333120, Total Data Read (bytes) = 2331840
# 42/42 [==============================] - 1s 14ms/step - loss: 0.5583 - accuracy: 0.7819
# 44/44 [==============================] - 0s 3ms/step
# Epoch 8: Early Accuracy = 0.79, Data Read in Epoch (bytes) = 333120, Total Data Read (bytes) = 2664960
# 42/42 [==============================] - 1s 14ms/step - loss: 0.5706 - accuracy: 0.7747
# 44/44 [==============================] - 0s 4ms/step
# Epoch 9: Early Accuracy = 0.80, Data Read in Epoch (bytes) = 333120, Total Data Read (bytes) = 2998080
# Training and Sequential Testing Time: 14.54 seconds

# %%
#train and test loss and scores respectively
train_loss_score=model.evaluate(X_train,y_train)
test_loss_score=model.evaluate(X_test,y_test)
print(train_loss_score)
print(test_loss_score)
# Out:
# 66/66 [==============================] - 1s 3ms/step - loss: 0.4965 - accuracy: 0.8141
# 44/44 [==============================] - 1s 4ms/step - loss: 2.1271 - accuracy: 0.3753
# [0.49654191732406616, 0.8141210079193115]
# [2.127051591873169, 0.37530824542045593]
